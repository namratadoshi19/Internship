# %%
# !pip install selenium
# !pip install bs4
# !pip install requests
# !pip install geopy

# %%
from bs4 import BeautifulSoup
import requests
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotVisibleException
from selenium.webdriver.common.by import By
import time
import numpy as np
import urllib
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException,ElementNotInteractableException,SessionNotCreatedException
from geopy.geocoders import Nominatim

# %%
driver=webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
driver.maximize_window()

# %% [markdown]
# # Q1

# %%
driver.get("https://www.amazon.in/")
item=driver.find_element(By.ID,"twotabsearchtextbox")
item.send_keys('guitar')
search=driver.find_element(By.ID,"nav-search-submit-button")
search.click()

# %% [markdown]
# # Q2

# %%
Brand_Name=[]
Nameofprd=[]
Price=[]
Return_Exch=[]
Exp_Del=[]
Avail=[]

# %%
product_urls=[]
start=0
end=3
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url[0:20]:
        product_urls.append(i.get_attribute("href"))
    next_button=driver.find_element (By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(2)

# %%
for url in product_urls[:20]:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        Brand_Name.append(brand.text)
    except NoSuchElementException:
        Brand_Name.append("-")
        
        
    try: 
        Name=driver.find_element(By.XPATH,'//span[@id="productTitle"]')
        Nameofprd.append(Name.text)
    except NoSuchElementException:
        Nameofprd.append("-")
        
        
    try:
        price=driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append("-")
        
    
    try:
        Exp_del=driver.find_element(By.XPATH,'//span[@class="a-text-bold"]')
        Exp_Del.append(Exp_del.text)
    except NoSuchElementException:
        Exp_Del.append("-")

# %%
df=pd.DataFrame({'Brand_name':Brand_Name[:20],'Product_Name':Nameofprd[:20],'Prices':Price[:20],'Expected_Del':Exp_Del[:20],'URLS':product_urls[:20]})
df
# Out:
#       Brand_name                                       Product_Name Prices  \
# 0         JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  1,949
# 1        Kadence  Kadence Frontier guitar with Online Guitar lea...  4,499
# 2        Kadence  Kadence rosewood Guitar Frontier Series, Elect...  5,499
# 3   MOCKING BIRD  MOCKING BIRD 38 inch Acoustic Guitar for Begin...  3,179
# 4         Intern  Intern INT-38C Right hand Acoustic Guitar Kit,...  2,299
# 5         JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  1,949
# 6         JUAREZ  Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 ...  1,739
# 7          musoo  musoo Solid Top Mahogany 26 Inch Tenor Ukulele...  3,699
# 8         Intern          Intern INT-38C Acoustic Guitar Kit (Blue)  1,998
# 9         Intern  Intern 38C Acoustic Steel-string Guitar Premiu...  1,999
# 10       Kadence  Kadence Frontier guitar with Online Guitar lea...  4,499
# ...

# %%
df.to_csv('guitar.csv')

# %% [markdown]
# # Q3

# %% [markdown]
# Cars

# %%
driver.get("https://images.google.com/")
item=driver.find_element(By.CLASS_NAME,"gLFyf")
item.send_keys('cars')
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    
img_urls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img_urls[i])
    file=open(r"E:\Sample_cars"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5696\3130309322.py in <module>
#      12 for i in range(len(img_urls)):
#      13     if i > 10:
# ---> 14         breakBy.XPATH,
#      15     print("Downloading {0} of {1} images".format(i,10))
#      16     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# Fruits

# %%
driver.get("https://images.google.com/")
item=driver.find_element(By.CLASS_NAME,"gLFyf")
item.send_keys('fruits')
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    
img_urls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img_urls[i])
    file=open(r"E:\Sample_fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5696\735928339.py in <module>
#      12 for i in range(len(img_urls)):
#      13     if i > 10:
# ---> 14         breakBy.XPATH,
#      15     print("Downloading {0} of {1} images".format(i,10))
#      16     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# Machine Learning

# %%
driver.get("https://images.google.com/")
item=driver.find_element(By.CLASS_NAME,"gLFyf")
item.send_keys('Machine Learning')
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    
img_urls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img_urls[i])
    file=open(r"E:\Sample_ML"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5696\3052125363.py in <module>
#      12 for i in range(len(img_urls)):
#      13     if i > 10:
# ---> 14         breakBy.XPATH,
#      15     print("Downloading {0} of {1} images".format(i,10))
#      16     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# Guitar

# %%
driver.get("https://images.google.com/")
item=driver.find_element(By.CLASS_NAME,"gLFyf")
item.send_keys('guitar')
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    
img_urls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img_urls[i])
    file=open(r"E:\Sample_GT"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5696\3561650007.py in <module>
#      12 for i in range(len(img_urls)):
#      13     if i > 10:
# ---> 14         breakBy.XPATH,
#      15     print("Downloading {0} of {1} images".format(i,10))
#      16     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# Cakes

# %%
driver.get("https://images.google.com/")
item=driver.find_element(By.CLASS_NAME,"gLFyf")
item.send_keys('Cakes')
search=driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")
    
img_urls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i > 10:
        breakBy.XPATH,
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img_urls[i])
    file=open(r"E:\Sample_CK"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5696\1349387616.py in <module>
#      12 for i in range(len(img_urls)):
#      13     if i > 10:
# ---> 14         breakBy.XPATH,
#      15     print("Downloading {0} of {1} images".format(i,10))
#      16     response=requests.get(img_urls[i])
#
# NameError: name 'breakBy' is not defined

# %% [markdown]
# # Q4

# %%
driver.get("https://www.flipkart.com/")
item1=driver.find_element(By.CLASS_NAME,"Pke_EE")
item1.send_keys('smartphone')
item1.click()

# %%
flip_dict={}
flip_dict["Brand_title"]=[]
flip_dict["Smartphone"]=[]
flip_dict["Colour"]=[]
RAM=[]
Storage=[]
PrimaryCam=[]
SecCam=[]
DisplaySize=[]
BatteryCap=[]
Price=[]

# %%
Product_URL=[]
start=0
end=1
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for i in url[0:25]:
        Product_URL.append(i.get_attribute("href"))
    time.sleep(2)

# %%
for url in Product_URL[:25]:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        flip_dict["Brand_title"].append(brand.text.split()[0])
    except NoSuchElementException:
        flip_dict["Brand_title"].append("-")
        
    
    try:
        SM=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        flip_dict["Smartphone"].append(SM.text.split(',')[0].split('(')[0])
    except NoSuchElementException:
        flip_dict["Smartphone"].append("-")
        
    
    try:
        Col=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        flip_dict["Colour"].append(Col.text.split(',')[0].split('(')[1])
    except NoSuchElementException:
        flip_dict["Colour"].append("-")
        
        
    try: 
        RM=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[1]')
        RAM.append(RM.text.split('|')[0])
    except NoSuchElementException:
        RAM.append("-")
    
        
    try: 
        ST=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[1]')
        Storage.append(ST.text.split('|')[1])
    except NoSuchElementException:
        Storage.append("-")
    
        
    try: 
        PC=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[3]')
        PrimaryCam.append(PC.text.split('|')[0])
    except NoSuchElementException:
        PrimaryCam.append("-")
    
        
    try: 
        SC=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[3]')
        SecCam.append(SC.text.split('|')[1])
    except NoSuchElementException:
        SecCam.append("-")
    
        
    try: 
        DS=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[2]')
        DisplaySize.append(DS.text)
    except NoSuchElementException:
        DisplaySize.append("-")
    
        
    try: 
        BT=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[4]')
        BatteryCap.append(BT.text)
    except NoSuchElementException:
        BatteryCap.append("-")
    
        
    try: 
        PR=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(PR.text)
    except NoSuchElementException:
        Price.append("-")

# %%
df4=pd.DataFrame({'Brand':flip_dict["Brand_title"][:25],'SmartPhone':flip_dict["Smartphone"][:25],'Color':flip_dict["Colour"][:25],'Ram':RAM[:25],'ROM':Storage[:25],'Prim_Cam':PrimaryCam[:25],'Sec_Cam':SecCam[:25],'Disp_Size':DisplaySize[:25],'Batt_Cap':BatteryCap[:25],'PRICE':Price[:25],'URL':Product_URL[:25]})
df4
# Out:
#        Brand                              SmartPhone            Color  \
# 0   Motorola                        Motorola G34 5G       Ocean Green
# 1       POCO                               POCO C55       Power Black
# 2   Motorola                        Motorola G34 5G          Ice Blue
# 3       POCO  POCO C51 - Locked with Airtel Prepaid        Royal Blue
# 4   MOTOROLA                     MOTOROLA g24 Power          Ink blue
# 5   MOTOROLA                     MOTOROLA g24 Power          Ink blue
# 6       POCO  POCO C51 - Locked with Airtel Prepaid       Power Black
# 7       vivo                            vivo T2x 5G   Sunstone Orange
# 8       vivo                            vivo T2x 5G       Aurora Gold
# 9       vivo                            vivo T2x 5G     Glimmer Black
# 10      vivo                            vivo T2x 5G       Marine Blue
# 11      vivo                            vivo T2x 5G     Glimmer Black
# ...

# %% [markdown]
# # Q5

# %%
driver.get("https://www.google.com/maps")
item=driver.find_element(By.ID,"searchboxinput")
item.send_keys('Pune')
search=driver.find_element(By.ID,"searchbox-searchbutton")
search.click()

# %%
geolocator = Nominatim(user_agent="MyApp")
location = geolocator.geocode("Pune")
print("The latitude of the location is: ", location.latitude)
print("The longitude of the location is: ", location.longitude)
# Out:
# The latitude of the location is:  18.521428
# The longitude of the location is:  73.8544541

# %% [markdown]
# # Q6

# %%
driver.get("https://www.digit.in/")
item=driver.find_element(By.ID,"woocommerce-product-search-field-0")
item.send_keys('Gaming Laptops')
item.click()

# %%
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
Brand_name=[]
Prod_des=[]
Processor=[]
Display=[]
OS=[]

# %%
Brand_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[3]/div/div/article/div[5]/div/div[2]/div/div/div/div/div[2]/div[2]/h3/a")
for i in Brand_tags:
    Brand=i.text
    Brand_name.append(Brand.split()[0])
    
Prod_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[3]/div/div/article/div[5]/div/div[2]/div/div/div/div/div[2]/div[2]/h3/a")
for i in Prod_tags:
    Prod=i.text
    Prod_des.append(Prod)
    
Proc_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[3]/div/div/article/div[5]/div/div[2]/div/div/div/div/div[2]/div[3]/div[2]/div[4]/div/span[2]")
for i in Proc_tags:
    Proc1=i.text
    Processor.append(Proc1)
    
Dis_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[3]/div/div/article/div[5]/div/div[2]/div/div/div/div/div[2]/div[3]/div[2]/div[2]/div/span[2]")
for i in Dis_tags:
    Disp=i.text
    Display.append(Disp)
    
Os_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[3]/div/div/article/div[5]/div/div[2]/div/div/div/div/div[2]/div[3]/div[2]/div[1]/div/span[2]")
for i in Os_tags:
    Os1=i.text
    OS.append(Os1)

# %%
df2=pd.DataFrame({'Brand':Brand_name,'Product':Prod_des,'PROCESSOR':Processor,'DISPLAY':Display,'Operating System':OS})
df2
# Out:
#     Brand                                            Product  \
# 0     MSI  MSI Titan GT77 HX 13VI-092IN 13th Gen Core i9-...
# 1    ASUS             ASUS ROG Strix SCAR 16 G634JYR-RA001WS
# 2     MSI  MSI Raider GE78HX 13VI-087IN 13th Gen Core i9-...
# 3    ASUS              ASUS ROG Strix SCAR 18 G834JY-N6056WS
# 4  Lenovo                               Lenovo Legion Pro 7i
# 5    OMEN                             OMEN by HP 17-ck2004TX
# 6    Dell                              Dell Alienware M18 R1
# 7    Dell                       Dell Alienware X16 R1 (2023)
# 8     MSI  MSI Raider GE67HX 12UHS-057IN 12th Gen Core i9...
# 9    Acer                            Acer Predator Helios 16
#
#                         PROCESSOR DISPLAY Operating System
# 0  13th Gen Intel Core i9-13980HX    17.3  Windows 11 Home
# 1  14th gen Intel Core i9-14900HX      16  Windows 11 Home
# 2  13th Gen Intel Core i9-13980HX      17  Windows 11 Home
# ...

# %% [markdown]
# # Q7

# %%
driver.get("https://www.forbes.com/billionaires/")

# %%
Rank=[]
Name=[]
Net_Worth=[]
Age=[]
Citi=[]
Source=[]

# %%
Nam_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[2]")
for i in Nam_tags[0:200]:
    Nam1=i.text
    Name.append(Nam1)

Ran_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[1]/div")
for i in Ran_tags[0:200]:
    Ran1=i.text
    Rank.append(Ran1)
    
NW_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[3]/div")
for i in NW_tags[0:200]:
    NW1=i.text
    Net_Worth.append(NW1)
    
AG_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[4]")
for i in AG_tags[0:200]:
    AG1=i.text
    Age.append(AG1)
    
CT_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[5]")
for i in CT_tags[0:200]:
    CT1=i.text
    Citi.append(CT1)
    
SC_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div/div/div[6]/div/span")
for i in SC_tags[0:200]:
    SC1=i.text
    Source.append(SC1)

# %%
print(len(Name),len(Rank),len(Net_Worth),len(Age),len(Citi),len(Source))
# Out:
# 16 17 15 15 15 15

# %%
df8=pd.DataFrame({'RANK':Rank[:15],'NAME':Name[:15],'NET_WORTH':Net_Worth[:15],'AGE':Age[:15],'Citizenship':Citi[:15],'SOURCE':Source[:15]})
df8
# Out:
#                                                  RANK  \
# 0                                                   1
# 1
# 2   Bernard Arnault oversees the LVMH empire of 75...
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
#
#                                      NAME NET_WORTH AGE    Citizenship  \
# 0                Bernard Arnault & family    $211 B  74         France
# ...

# %% [markdown]
# # Q8

# %%
driver.get("https://www.youtube.com/watch?v=ummGYA6gWME&list=PL9bw4S5ePsEHil8ve8D0fRLf4ewqZ6hNZ")

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")

# %%
Comment=[]
Upvote=[]
time=[]

# %%
CM_tags=driver.find_elements(By.XPATH,"/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer/ytd-comment-renderer/div[3]/div[2]/div[2]/ytd-expander/div")
for i in CM_tags[0:100]:
    CM1=i.text
    Comment.append(CM1)

UP_tags=driver.find_elements(By.XPATH,"/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer/ytd-comment-renderer/div[3]/div[2]/ytd-comment-action-buttons-renderer/div[1]/span[2]")
for i in UP_tags[0:100]:
    UP1=i.text
    Upvote.append(UP1)
    
Tm_tags=driver.find_elements(By.XPATH,"/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer/ytd-comment-renderer/div[3]/div[2]/div[1]/div[2]/yt-formatted-string/a")
for i in Tm_tags[0:100]:
    tm1=i.text
    time.append(tm1)

# %%
print(len(Comment),len(Upvote),len(time))
# Out:
# 20 20 20

# %%
df12=pd.DataFrame({'Comments':Comment,'Upvotes':Upvote,'Time':time})
df12
# Out:
#                                              Comments Upvotes  \
# 0   The first thing that caught my eyes...BSF...wr...     397
# 1        It's a best remake of this song\nJai hind 🇮🇳     432
# 2    "V Unbeatable" made this song more enthusiastic      281
# 3   Proud 🇮🇳 to be an Hindustani🇮🇳\nJai hind🇮🇳 jai...      39
# 4   Who's here for the best acrobatic dance group ...     510
# 5   I was there when it was shot... love  the feel...     703
# 6           Udit Narayan ji's voice still like 90's ️      52
# 7   I proud to be an indian \nI am in NCC with eff...     265
# 8   26 january se pehle ye song\nHappy republic da...      41
# 9   सबसे आगे होंगे "हिंदुस्थानी" !!!\n🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳...     551
# 10  Chaahe kithna Zor lagalo subse aage honge HIND...      59
# 11                   Proud to be Indian \nJai Hind 🇮🇳     331
# 12  Everyone noticed varun dhawn but their is v un...    1.6K
# 13  First time in my entire life I liked a remake....     917
# ...

# %% [markdown]
# # Q9

# %%
driver.get("https://www.hostelworld.com/")

# %%
location=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div/div/div[2]/input")
location.send_keys('London')

# %%
H_name=[]
Dis=[]
Rat=[]
T_rev=[]
O_rev=[]
P_Pr=[]
D_Pr=[]

# %%
HN_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div[1]/div/span")
for i in HN_tags[0:30]:
    HN1=i.text
    H_name.append(HN1)
    
DS_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div/span")
for i in DS_tags[0:30]:
    DS1=i.text
    Dis.append(DS1)
    
RT_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div[1]/div/div/div[1]/span[1]")
for i in RT_tags[0:30]:
    RT1=i.text
    Rat.append(RT1)
    
TR_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div[1]/div/div/div[2]/span")
for i in TR_tags[0:30]:
    TR1=i.text
    T_rev.append(TR1)
    
PPR_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div[4]/div/div[1]/div/strong")
for i in PPR_tags[0:30]:
    PPR1=i.text
    P_Pr.append(PPR1)

DP_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div/div[6]/div/a/a/div[2]/div[4]/div/div[2]/div[3]/strong")
for i in DP_tags[0:30]:
    DP1=i.text
    D_Pr.append(DP1)

# %%
print(len(H_name),len(Dis),len(Rat),len(T_rev),len(P_Pr),len(D_Pr))
# Out:
# 30 30 30 30 13 14

# %%
df10=pd.DataFrame({'Hostel':H_name[:13],'Distance':Dis[:13],'Ratings':Rat[:13],'Reviews':T_rev[:13],'Priv_Price':P_Pr[:13],'Dorm_Price':D_Pr[:13]})
df10
# Out:
#                                Hostel                  Distance Ratings  \
# 0         Wombat's City Hostel London                    Hostel     9.2
# 1       Palmers Lodge - Swiss Cottage  - 3.6km from city centre     8.7
# 2                    NX London Hostel                               8.9
# 3                Urbany Hostel London                    Hostel     9.6
# 4                 Onefam Notting Hill  - 6.5km from city centre     9.6
# 5            St Christopher's Village                               7.6
# 6                     Onefam Waterloo                    Hostel     9.6
# 7                    Generator London  - 6.1km from city centre     7.5
# 8                  No.8 Seven Sisters                               7.8
# 9   Safestay London Elephant & Castle                               7.5
# 10                           Clink261                    Hostel     8.3
# 11       No.8 Willesden Hostel London  - 5.4km from city centre     7.0
# ...
