# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")

# %% [markdown]
# # Q1

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[5]/div[2]/div[3]/label/p/span[1]")
location.click()

# %%
sal=driver.find_element(By.XPATH,"/html/body/div/div/main/div[1]/div[1]/div/div/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
sal.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,"/html/body/div/div/main/div[1]/div[2]/div[2]/div/div/div/div[1]/a")
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//span[@class='locWdth']")
for i in location_tags:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"/html/body/div/div/main/div[1]/div[2]/div[2]/div/div/div/div[2]/span/a[1]")
for i in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,"//span[@class='expwdth']")
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
df=pd.DataFrame({'Job_title':job_title,'Job_location':job_location,'Company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                             Job_title  \
# 0                                      Data Scientist
# 1                                      Data Scientist
# 2                                 Lead Data Scientist
# 3                                      Data Scientist
# 4              Lead Customer Success - Data Scientist
# 5   JOB Opening // Data science // Neosoft Mumbai ...
# 6                                      Data Scientist
# 7                                      Data Scientist
# 8                               Python and ML Trainer
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                           Freelance Data Scientist
# ...

# %% [markdown]
# # Q2

# %%
driver.get("https://www.shine.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"input")
designation.click()

# %%
designation1=driver.find_element(By.ID,"id_q")
designation1.send_keys('Data Analyst')
designation1.click()

# %%
location=driver.find_element(By.ID,"id_loc")
location.send_keys('Bangalore')
location.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]
experience_required1=[]

# %%
title_tags1=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[4]/div/div[2]/div[1]/div/div/div/div[1]/div[1]/h2/a")
for i in title_tags1:
    title=i.text
    job_title1.append(title)
    
location_tags1=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[4]/div/div[2]/div[1]/div/div/div/div[1]/div[1]/div[3]/div[2]")
for i in location_tags1:
    location=i.text
    job_location1.append(location)
    
company_tags1=driver.find_elements(By.XPATH,"//div[@class='jobCard_jobCard_cName__mYnow']")
for i in company_tags1:
    company=i.text
    company_name1.append(company)
    
experience_tags1=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[4]/div/div[2]/div[1]/div/div/div/div[1]/div[1]/div[3]/div[1]")
for i in experience_tags1:
    exp=i.text
    experience_required1.append(exp)

# %%
print(len(job_title1),len(job_location1),len(company_name1),len(experience_required1))
# Out:
# 20 20 20 20

# %%
df=pd.DataFrame({'Job_title':job_title,'Job_location':job_location,'Company_name':company_name,'Exp_required':experience_required1})
df
# Out:
#                                             Job_title  \
# 0                                      Data Scientist
# 1                                      Data Scientist
# 2                                 Lead Data Scientist
# 3                                      Data Scientist
# 4              Lead Customer Success - Data Scientist
# 5   JOB Opening // Data science // Neosoft Mumbai ...
# 6                                      Data Scientist
# 7                                      Data Scientist
# 8                               Python and ML Trainer
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11                                     Data Scientist
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                           Freelance Data Scientist
# ...

# %% [markdown]
# # Q3

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
Rating=[]
Review_summ=[]
Full_rev=[]

# %%
start=0
end=10
for page in range(start,end):
    Rating_tags=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
    for i in Rating_tags:
        Rating.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
for page in range(start,end):
    Review_tags=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in Review_tags:
        Review_summ.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
for page in range(start,end):
    Full_tags=driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']")
    for i in Full_tags:
        Full_rev.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(Rating),len(Review_summ),len(Full_rev))
# Out:
# 100 100 100

# %%
df3=pd.DataFrame({'rating':Rating,'review_summ':Review_summ,'full_rev':Full_rev})
df3
# Out:
#    rating          review_summ  \
# 0       5    Worth every penny
# 1       5  Best in the market!
# 2       5            Wonderful
# 3       5            Fabulous!
# 4       5             Terrific
# ..    ...                  ...
# 95      5               Super!
# 96      5            Fabulous!
# 97      5    Terrific purchase
# 98      5            Must buy!
# 99      5   Highly recommended
#
#                                              full_rev
# 0   Feeling awesome after getting the delivery of ...
# 1                                         Good Camera
# 2                              This is amazing at all
# 3                     Super🔥 and good performance 👌❤️
# 4                                      Very very good
# ..                                                ...
# 95                        Good product 👌I love iPhone
# 96  It’s very good battery life and display and vi...
# 97                                 Value for money 🖤🖤
# ...

# %% [markdown]
# # Q4

# %%
driver.get("https://www.flipkart.com/")

# %%
Product=driver.find_element(By.CLASS_NAME,"Pke_EE")
Product.send_keys('sneakers')
Product.click()

# %%
brand=[]
prod_des=[]
price=[]

# %%
start=0
end=3
for page in range(start,end):
    Brand_tags=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in Brand_tags:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
for page in range(start,end):
    prod_tags=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in prod_tags:
        prod_des.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
for page in range(start,end):
    price_tags=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in price_tags:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand),len(prod_des),len(price))
# Out:
# 120 96 118

# %%
SN=pd.DataFrame({"Brand": brand[:96],"Prod_des": prod_des[:96],"Price": price[:96]})
SN
# Out:
#         Brand                                           Prod_des   Price
# 0    URBANBOX  Layasa New Attractive Sneakers Lightweight Sne...    ₹299
# 1    HOTSTYLE  Premium Sports Shoes For Men Pack Of 2 Sneaker...    ₹383
# 2    URBANBOX  Stylish Sneakers Shoes for Women And Girls Sne...    ₹299
# 3   Deals4you  Sneaker Casual Shoes For Men | Soft Cushion In...    ₹439
# 4    RED TAPE  Sneaker Casual Shoes for Men | Soft Cushioned ...  ₹1,179
# ..        ...                                                ...     ...
# 91       aadi                   URBAN RIDER PRO Sneakers For Men  ₹1,079
# 92   RED TAPE  Flat Sole Sneakers Shoes for all Day wear with...    ₹549
# 93      BIRDE                                   Sneakers For Men    ₹474
# 94      Fizoo                                 Sneakers For Women    ₹544
# 95      BIRDE                             PANAL Sneakers For Men    ₹374
#
# [96 rows x 3 columns]

# %% [markdown]
# # Q5

# %%
driver.get("https://www.amazon.in/")

# %%
item=driver.find_element(By.ID,"twotabsearchtextbox")
item.send_keys('laptop')

# %%
search=driver.find_element(By.ID,"nav-search-submit-text")
search.click()

# %%
title=[]
ratings=[]
price1=[]

# %%
title_tags2=driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title_tags2:
    title1=i.text
    title.append(title1)

rat_tags2=driver.find_elements(By.XPATH,"//span[@class='a-size-base s-underline-text']")
for i in rat_tags2:
    rat1=i.text
    ratings.append(rat1)
    
price_tags2=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price_tags2:
    pr1=i.text
    price1.append(pr1)

# %%
print(len(title),len(ratings),len(price1))
# Out:
# 48 50 54

# %%
LP=pd.DataFrame({"Title": title[:11],"Ratings": ratings[:11],"Price1": price1[:11]})
LP
# Out:
#                                                 Title Ratings    Price1
# 0   asus Zenbook 14X OLED Business Laptop | 14.5''...      88    59,990
# 1   MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...     459    49,990
# 2   Lenovo IdeaPad Slim 3 Intel Core i7 12th Gen 1...       4    49,990
# 3   Lenovo Yoga Slim7 Carbon Intel Evo i7 1260P 13...     146    62,990
# 4   HP Pavilion X360 11th Gen Intel Core i7 14" (3...     227  1,19,990
# 5   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...     450    67,999
# 6   ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...       2    74,990
# 7   Acer Travelmate Business Laptop Intel Core i7-...      88    59,990
# 8   Dell Inspiron 5430 Laptop, 13th Gen Intel Core...       1    49,990
# 9   Dell G15 5530 Gaming Laptop, Intel i7-13650HX/...     357    86,730
# 10  HP Victus Gaming Laptop, 12th Gen Intel Core i...     468    99,990

# %% [markdown]
# # Q6

# %%
driver.get("https://www.azquotes.com/top_quotes.html")

# %%
Quote=[]
Author=[]
Typeofquote=[]

# %%
for i in range(0,10):
    Quote_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Quote_tags:
        Quote1=i.text
        Quote.append(i.text.split('\n')[0])
    
    Author_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Author_tags:
        Author1=i.text
        Author.append(i.text.split('\n')[1])
    
    Type_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Type_tags:
        Type1=i.text
        Typeofquote.append(i.text.split('\n')[2])

# %%
AZ=pd.DataFrame({"Quotes": Quote[:1000],"Authors": Author[:1000],"TypeofQuotes": Typeofquote[:1000]})
AZ
# Out:
#                                                 Quotes               Authors  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Q7

# %%
driver.get("https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1")

# %%
Name=[]
Born_Dead=[]
Termofoffice=[]
Remark=[]

# %%
Name_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div/table/tbody/tr/td[2]/div")
for i in Name_tags:
    Name1=i.text
    Name.append(Name1)

# %%
Name
# Out:
# []

# %%
Name_tags=driver.find_elements(By.XPATH,"//div[@class='TableData']/table/tbody/tr/td[2]/div")
for i in Name_tags:
    Name1=i.text
    Name.append(Name1)

# %%
/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div/table/tbody/tr[2]/td[2]/div/strong/a

# %%
/html/body/div[1]/main/div[1]/div[1]/article/div[3]/div[6]/div/table/tbody/tr[3]/td[2]/div

# %%
Name_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[2]/p")
for i in Name_tags:
    Name1=i.text
    Name.append(Name1)
    
Borndead_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[3]/p")
for i in Borndead_tags:
    Bornd1=i.text
    Born_Dead.append(Bornd1)

Term_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[4]/p")
for i in Term_tags:
    Term1=i.text
    Termofoffice.append(Term1)
    
Remark_tags=driver.find_elements(By.XPATH,"//div[@class='TableData']/table/tbody/tr/td[5]/p")
for i in Remark_tags:
    Remark1=i.text
    Remark.append(Remark1)

# %%
Name_tags=driver.find_elements(By.XPATH,"//div[@class='TableData']/table/tbody/tr/td[2]/a")
for i in Name_tags:
    Name1=i.text
    Name.append(Name1)

# %%
PM=pd.DataFrame({"Names": Name[:18],"BornDead": Born_Dead[:18],"TermsOfOffice": Termofoffice[:18],"Remarks":Remark[:18]})
PM

# %%
jupyter notebook is getting hanged while connecting and working on this site

# %% [markdown]
# # Q8

# %%
driver.get("https://www.motor1.com/features/category/lists/")

# %%
expensivecars=driver.find_element(By.XPATH,"/html/body/div[9]/div[2]/div/div/div[3]/div/div/div/form/input")
expensivecars.send_keys('50 most expensive cars in the world')

# %%
search=driver.find_element(By.CLASS_NAME,"features-search_input features-search_input-submit")
search.click()

# %%
driver.get("https://www.motor1.com/features/308149/most-expensive-new-cars-ever/")

# %%
Carname=[]
Desc=[]
Price=[]

# %%
Car_tags=driver.find_elements(By.XPATH,"//h3[@class='subheader']")
for i in Car_tags:
    Car1=i.text
    Carname.append(Car1)
    
Desc_tags=driver.find_elements(By.XPATH,'/html/body/div[9]/div[7]/div[2]/div[1]/div[2]/div[2]/p')
for i in Desc_tags:
    Des1=(i.text)
    Desc.append(Des1)
    
Price_tags=driver.find_elements(By.XPATH,"//strong")
for i in Price_tags:
    Price.append(i.text)

# %%
EM=pd.DataFrame({"CarNames": Carname[:50],"Description": Desc[:50],"Prices": Price[:50]})
EM
# Out:
#                               CarNames  \
# 0                  Aston Martin Valour
# 1                         McLaren Elva
# 2                          Czinger 21C
# 3                        Ferrari Monza
# 4                   Gordon Murray T.33
# 5                    Koenigsegg Gemera
# 6                          Zenvo TSR-S
# 7                   Hennessey Venom F5
# 8                      Bentley Bacalar
# 9        Hispano Suiza Carmen Boulogne
# 10              Bentley Mulliner Batur
# 11                        Deus Vayanne
# 12                         SSC Tuatara
# 13                         Lotus Evija
# 14                 Aston Martin Vulcan
# 15                          Delage D12
# 16                 Ferrari Daytona SP3
# 17                   McLaren Speedtail
# 18                        Rimac Nevera
# 19                       Pagani Utopia
# 20                Pininfarina Battista
# 21                  Gordon Murray T.50
# 22                Lamborghini Countach
# ...
