# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Restaurant-Food-Cost.csv')
df
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
df.head(15)
# Out:
#                         TITLE  RESTAURANT_ID  \
# 0               CASUAL DINING           9438
# 1           CASUAL DINING,BAR          13198
# 2               CASUAL DINING          10915
# 3                 QUICK BITES           6346
# 4              DESSERT PARLOR          15387
# 5               CASUAL DINING           5618
# 6                        CAFÉ           4383
# 7                MICROBREWERY           1249
# 8                 QUICK BITES           7062
# 9                 QUICK BITES          10109
# 10              CASUAL DINING             38
# 11  QUICK BITES,BEVERAGE SHOP            844
# 12              CASUAL DINING            938
# 13              CASUAL DINING           4319
# 14                QUICK BITES          15024
#
#                                       CUISINES  \
# 0                  Malwani, Goan, North Indian
# 1               Asian, Modern Indian, Japanese
# 2   North Indian, Chinese, Biryani, Hyderabadi
# ...

# %%
df.shape
# Out:
# (12690, 9)

# %% [markdown]
# There are 12690 rows and 9 columns out of which 1 is target variable and remaining 8 are independent variables.

# %%
df.columns
# Out:
# Index(['TITLE', 'RESTAURANT_ID', 'CUISINES', 'TIME', 'CITY', 'LOCALITY',
#        'RATING', 'VOTES', 'COST'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['TITLE',
#  'RESTAURANT_ID',
#  'CUISINES',
#  'TIME',
#  'CITY',
#  'LOCALITY',
#  'RATING',
#  'VOTES',
#  'COST']

# %%
df.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 1416

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12690 entries, 0 to 12689
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TITLE          12690 non-null  object
#  1   RESTAURANT_ID  12690 non-null  int64
#  2   CUISINES       12690 non-null  object
#  3   TIME           12690 non-null  object
#  4   CITY           12578 non-null  object
#  5   LOCALITY       12592 non-null  object
#  6   RATING         12688 non-null  object
#  7   VOTES          11486 non-null  object
#  8   COST           12690 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 892.4+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical Columns:",categorical_col)
print("\n")

#checking for numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns:",numerical_col)
# Out:
# Categorical Columns: ['TITLE', 'CUISINES', 'TIME', 'CITY', 'LOCALITY', 'RATING', 'VOTES']
#
#
# Numerical Columns: ['RESTAURANT_ID', 'COST']

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#                No. of unique values
# TITLE                           113
# RESTAURANT_ID                 11892
# CUISINES                       4155
# TIME                           2689
# CITY                            359
# LOCALITY                       1416
# RATING                           32
# VOTES                          1847
# COST                             86

# %%
ax=sns.stripplot(x='COST',data=df)
print(df['COST'].value_counts())
# Out:
# 300      1595
# 400      1357
# 500      1300
# 200      1031
# 600       806
#          ...
# 8000        1
# 14000       1
# 5200        1
# 80          1
# 70          1
# Name: COST, Length: 86, dtype: int64

# %% [markdown]
# Most of the restaurants have 1500-2500 cost

# %%
sns.stripplot(df['TITLE'])
# Out:
# <AxesSubplot:xlabel='TITLE'>

# %%
sns.stripplot(df['RESTAURANT_ID'])
# Out:
# <AxesSubplot:xlabel='RESTAURANT_ID'>

# %%
sns.stripplot(df['CUISINES'])
# Out:
# <AxesSubplot:xlabel='CUISINES'>

# %%
sns.pairplot(df,hue='COST',palette='Dark2')
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# RESTAURANT_ID       AxesSubplot(0.125,0.53;0.110714x0.35)
# COST             AxesSubplot(0.257857,0.53;0.110714x0.35)
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        TITLE  RESTAURANT_ID  CUISINES    TIME   CITY  LOCALITY  RATING  \
# 0       31.0           9438    2627.0   739.0  320.0     285.0    17.0
# 1       33.0          13198     289.0  1885.0   67.0    1046.0    23.0
# 2       31.0          10915    2976.0   661.0   67.0    1101.0    19.0
# 3       95.0           6346    4130.0   275.0  222.0     136.0    22.0
# 4       50.0          15387    1766.0   615.0  222.0     620.0    19.0
# ...      ...            ...       ...     ...    ...       ...     ...
# 12685   95.0          13228    2934.0  1144.0  131.0     342.0    19.0
# 12686   33.0           9686    2143.0  1177.0  222.0     133.0    24.0
# 12687   71.0          11133    2088.0  1137.0  239.0    1342.0    21.0
# 12688   31.0           6134    3506.0  1837.0   67.0     631.0    16.0
# 12689   31.0           6430    2946.0   835.0  131.0    1333.0    15.0
#
#         VOTES  COST
# 0      1278.0  1200
# 1       950.0  1500
# 2       712.0   800
# 3       787.0   800
# ...

# %%
np.mean(df["CITY"])
# Out:
# 142.95174113531564

# %%
df["CITY"]=df["CITY"].fillna(df["CITY"].mean())

# %%
np.mean(df["LOCALITY"])
# Out:
# 654.7556385006353

# %%
df["LOCALITY"]=df["LOCALITY"].fillna(df["LOCALITY"].mean())

# %%
np.mean(df["RATING"])
# Out:
# 18.795712484237075

# %%
df["RATING"]=df["RATING"].fillna(df["RATING"].mean())

# %%
np.mean(df["VOTES"])
# Out:
# 969.3723663590458

# %%
df["VOTES"]=df["VOTES"].fillna(df["VOTES"].mean())

# %%
df.isnull().sum()
# Out:
# TITLE            0
# RESTAURANT_ID    0
# CUISINES         0
# TIME             0
# CITY             0
# LOCALITY         0
# RATING           0
# VOTES            0
# COST             0
# dtype: int64

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#           TITLE  RESTAURANT_ID  CUISINES      TIME      CITY  LOCALITY  \
# 0      0.868887       0.372692  0.325408  0.584658  2.117374  0.928487
# 1      0.807839       1.207377  1.616381  0.934369  0.908330  0.982447
# 2      0.868887       0.700572  0.615265  0.688048  0.908330  1.120557
# 3      1.084647       0.313702  1.573701  1.199692  0.945362  1.302639
# 4      0.288931       1.693314  0.389682  0.749021  0.945362  0.087274
# ...         ...            ...       ...       ...       ...       ...
# 12685  1.084647       1.214036  0.580382  0.047829  0.142935  0.785356
# 12686  0.807839       0.427746  0.076570  0.004088  0.945362  1.310172
# 12687  0.352072       0.748966  0.122250  0.057108  1.148670  1.725728
# 12688  0.868887       0.360764  1.055448  0.870745  0.908330  0.059652
# 12689  0.868887       0.295055  0.590349  0.457410  0.142935  1.703128
#
#          RATING     VOTES      COST
# 0      0.290517  0.646108  0.868846
# 1      0.680185  0.040556  1.347331
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   13,    84,    85,   156,   178,   208,   235,   253,   308,
#          329,   337,   369,   374,   379,   392,   396,   422,   428,
#          438,   452,   453,   455,   469,   473,   480,   502,   508,
#          563,   577,   604,   615,   625,   644,   690,   731,   749,
#          751,   772,   787,   831,   838,   839,   874,   911,   919,
#          949,   966,   967,   973,   981,   993,   994,  1009,  1054,
#         1126,  1133,  1193,  1196,  1205,  1227,  1287,  1288,  1297,
#         1345,  1365,  1366,  1395,  1468,  1470,  1472,  1475,  1502,
#         1543,  1555,  1581,  1594,  1596,  1597,  1632,  1635,  1657,
#         1696,  1701,  1711,  1748,  1759,  1764,  1778,  1792,  1806,
#         1828,  1839,  1855,  1878,  1884,  1884,  1903,  1916,  1930,
#         1931,  1983,  2025,  2039,  2053,  2082,  2092,  2096,  2100,
#         2109,  2111,  2115,  2124,  2205,  2207,  2251,  2254,  2313,
# ...

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#        TITLE  RESTAURANT_ID  CUISINES    TIME   CITY  LOCALITY  RATING  \
# 0       31.0           9438    2627.0   739.0  320.0     285.0    17.0
# 1       33.0          13198     289.0  1885.0   67.0    1046.0    23.0
# 2       31.0          10915    2976.0   661.0   67.0    1101.0    19.0
# 3       95.0           6346    4130.0   275.0  222.0     136.0    22.0
# 4       50.0          15387    1766.0   615.0  222.0     620.0    19.0
# ...      ...            ...       ...     ...    ...       ...     ...
# 12685   95.0          13228    2934.0  1144.0  131.0     342.0    19.0
# 12686   33.0           9686    2143.0  1177.0  222.0     133.0    24.0
# 12687   71.0          11133    2088.0  1137.0  239.0    1342.0    21.0
# 12688   31.0           6134    3506.0  1837.0   67.0     631.0    16.0
# 12689   31.0           6430    2946.0   835.0  131.0    1333.0    15.0
#
#         VOTES  COST
# 0      1278.0  1200
# 1       950.0  1500
# 2       712.0   800
# 3       787.0   800
# ...

# %%
df1.shape
# Out:
# (11972, 9)

# %%
df1.skew()
# Out:
# TITLE           -0.071799
# RESTAURANT_ID    0.003724
# CUISINES        -0.216128
# TIME             0.342022
# CITY             0.291867
# LOCALITY         0.331628
# RATING           0.143176
# VOTES           -0.189518
# COST             1.737557
# dtype: float64

# %%
df1.describe()
# Out:
#               TITLE  RESTAURANT_ID      CUISINES          TIME          CITY  \
# count  11972.000000    11972.00000  11972.000000  11972.000000  11972.000000
# mean      59.687437     7770.67992   2233.638991   1159.056131    141.766362
# std       32.887386     4511.15727   1208.458593    746.852217     84.899183
# min        0.000000        0.00000      0.000000      0.000000      0.000000
# 25%       31.000000     3861.00000   1181.000000    555.000000     67.000000
# 50%       57.000000     7765.00000   2398.000000   1123.000000    131.000000
# 75%       95.000000    11717.25000   3231.250000   1829.000000    222.000000
# max      112.000000    15573.00000   4154.000000   2688.000000    358.000000
#
#            LOCALITY        RATING         VOTES          COST
# count  11972.000000  11972.000000  11972.000000  11972.000000
# mean     653.645633     19.502054    968.118078    612.580271
# std      398.328512      4.999720    487.237590    457.127247
# ...

# %%
cor=df1.corr()
cor
# Out:
#                   TITLE  RESTAURANT_ID  CUISINES      TIME      CITY  \
# TITLE          1.000000       0.003279  0.241903  0.063566 -0.010357
# RESTAURANT_ID  0.003279       1.000000  0.055458  0.009362  0.005575
# CUISINES       0.241903       0.055458  1.000000  0.109389  0.025223
# TIME           0.063566       0.009362  0.109389  1.000000 -0.019131
# CITY          -0.010357       0.005575  0.025223 -0.019131  1.000000
# LOCALITY       0.032542      -0.000713  0.015832 -0.015070  0.042621
# RATING        -0.075325       0.020995 -0.054030  0.026774  0.078308
# VOTES          0.002239       0.011147 -0.002811  0.008121  0.000370
# COST          -0.378214       0.039432 -0.038540 -0.016084  0.043686
#
#                LOCALITY    RATING     VOTES      COST
# TITLE          0.032542 -0.075325  0.002239 -0.378214
# RESTAURANT_ID -0.000713  0.020995  0.011147  0.039432
# CUISINES       0.015832 -0.054030 -0.002811 -0.038540
# TIME          -0.015070  0.026774  0.008121 -0.016084
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr(),linewidth=0.1,fmt='.1g',linecolor='black',annot=True,cmap='Blues_r')
plt.yticks(rotation=0);
plt.show()

# %%
cor['COST'].sort_values(ascending=False)
# Out:
# COST             1.000000
# RATING           0.230465
# CITY             0.043686
# RESTAURANT_ID    0.039432
# VOTES           -0.006386
# TIME            -0.016084
# LOCALITY        -0.016906
# CUISINES        -0.038540
# TITLE           -0.378214
# Name: COST, dtype: float64

# %%
plt.figure(figsize=(22,7))
df1.corr()['COST'].sort_values(ascending=False).drop(['COST']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between label and features using barplot',fontsize=20)
plt.show()

# %%
x=df1.drop('COST',axis=1)
y=df1['COST']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#           TITLE  RESTAURANT_ID  CUISINES      TIME      CITY  LOCALITY  \
# 0     -0.872329       0.369615  0.325520 -0.562459  2.099444 -0.925520
# 1     -0.811513       1.203138 -1.609257  0.972045 -0.880686  0.985043
# 2     -0.872329       0.697039  0.614330 -0.666902 -0.880686  1.123126
# 3      1.073787      -0.315826  1.569305 -1.183759  0.945086 -1.299599
# 4     -0.294576       1.688400 -0.386988 -0.728496  0.945086 -0.084471
# ...         ...            ...       ...       ...       ...       ...
# 11967  1.073787       1.209789  0.579573 -0.020160 -0.126819 -0.782416
# 11968 -0.811513       0.424592 -0.075007  0.024027  0.945086 -1.307131
# 11969  0.343993       0.745365 -0.120521 -0.029533  1.145331  1.728179
# 11970 -0.872329      -0.362822  1.052923  0.907773 -0.880686 -0.056854
# 11971 -0.872329      -0.297204  0.589504 -0.433914 -0.126819  1.705584
#
#          RATING     VOTES
# 0     -0.500460  0.636024
# 1      0.699658 -0.037187
# 2     -0.100421 -0.525675
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Feature']=x.columns
vif
# Out:
#    VIF values        Feature
# 0    1.069487          TITLE
# 1    1.003895  RESTAURANT_ID
# 2    1.078777       CUISINES
# 3    1.015851           TIME
# 4    1.009732           CITY
# 5    1.003638       LOCALITY
# 6    1.015818         RATING
# 7    1.000327          VOTES

# %%
y.value_counts()
# Out:
# 300     1505
# 400     1292
# 500     1267
# 200      929
# 600      794
# 250      633
# 800      594
# 700      579
# 350      525
# 1000     432
# 150      427
# 450      349
# 1200     327
# 1500     306
# 550      189
# 650      182
# 900      176
# 100      161
# 2000     157
# 750      151
# 1800     125
# 1100     124
# 1300     120
# 1400     118
# 1600     109
# 2500      86
# 850       68
# 1700      47
# 2200      34
# 950       29
# 1900      24
# 2400      19
# 2100      16
# 2300       9
# 120        9
# 1250       6
# 50         6
# 1350       6
# 1550       5
# 1150       5
# 180        4
# 1750       4
# 1850       4
# 1650       3
# 130        2
# 1050       2
# 1450       2
# 60         2
# 299        1
# 320        1
# 1950       1
# 370        1
# 313        1
# 599        1
# 140        1
# 80         1
# 1260       1
# Name: COST, dtype: int64

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x1,y1=sm.fit_resample(x,y)
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11384\3944172052.py in <module>
#       2 from imblearn.over_sampling import SMOTE
#       3 sm=SMOTE()
# ----> 4 x1,y1=sm.fit_resample(x,y)
#
# ~\AppData\Roaming\Python\Python39\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      86         )
#      87
# ---> 88         output = self._fit_resample(X, y)
#      89
#      90         y_ = (
#
# ~\AppData\Roaming\Python\Python39\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     353
#     354             self.nn_k_.fit(X_class)
# ...

# %%
y1.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11384\4175980875.py in <module>
# ----> 1 y1.value_counts()
#
# NameError: name 'y1' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is',maxAccu,'at random_state',maxRS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11384\2908177151.py in <module>
#       5 maxRS=0
#       6 for i in range(1,200):
# ----> 7     x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
#       8     RFR=RandomForestClassifier()
#       9     RFR.fit(x_train,y_train)
#
# NameError: name 'x1' is not defined

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11384\204419258.py in <module>
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)
#
# NameError: name 'train_test_split' is not defined
